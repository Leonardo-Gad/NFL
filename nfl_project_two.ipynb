# %%
import pandas as pd

# %%
df = pd.read_csv('/home/whitegandalf/Downloads/archive_nfl/Basic_Stats.csv')

# %%
df.head()
# Out:
#     Age        Birth Place    Birthday           College Current Status
# 0   NaN  Grand Rapids , MI   5/23/1921        Notre Dame        Retired  \
# 1   NaN        Dayton , OH  12/21/1930            Dayton        Retired
# 2  56.0        Temple , TX   9/11/1960    Louisiana Tech        Retired
# 3  30.0   New Orleans , LA   9/30/1986               LSU        Retired
# 4  25.0       Detroit , MI   3/31/1992  Central Michigan         Active
#
#           Current Team  Experience  Height (inches)     High School
# 0                  NaN   3 Seasons             71.0             NaN  \
# 1                  NaN    1 Season             70.0             NaN
# 2                  NaN    1 Season             74.0             NaN
# 3                  NaN   5 Seasons             73.0             NaN
# 4  Pittsburgh Steelers  3rd season             77.0  Clintondale HS
#
#           High School Location            Name  Number            Player Id
# ...

# %%
# Colunas do dataframe

list(df)
# Out:
# ['Age',
#  'Birth Place',
#  'Birthday',
#  'College',
#  'Current Status',
#  'Current Team',
#  'Experience',
#  'Height (inches)',
#  'High School',
#  'High School Location',
#  'Name',
#  'Number',
#  'Player Id',
#  'Position',
#  'Weight (lbs)',
#  'Years Played']

# %%
# Colunas do dataframe

df.columns
# Out:
# Index(['Age', 'Birth Place', 'Birthday', 'College', 'Current Status',
#        'Current Team', 'Experience', 'Height (inches)', 'High School',
#        'High School Location', 'Name', 'Number', 'Player Id', 'Position',
#        'Weight (lbs)', 'Years Played'],
#       dtype='object')

# %%
# atributo dtypes
df.dtypes
# Out:
# Age                     float64
# Birth Place              object
# Birthday                 object
# College                  object
# Current Status           object
# Current Team             object
# Experience               object
# Height (inches)         float64
# High School              object
# High School Location     object
# Name                     object
# Number                  float64
# Player Id                object
# Position                 object
# Weight (lbs)            float64
# Years Played             object
# dtype: object

# %%
# Function that returns the summary of non-missing values for each column instead

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17172 entries, 0 to 17171
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   13504 non-null  float64
#  1   Birth Place           14794 non-null  object
#  2   Birthday              16835 non-null  object
#  3   College               17133 non-null  object
#  4   Current Status        17172 non-null  object
#  5   Current Team          3096 non-null   object
#  6   Experience            17133 non-null  object
#  7   Height (inches)       17026 non-null  float64
#  8   High School           2514 non-null   object
#  9   High School Location  2510 non-null   object
#  10  Name                  17172 non-null  object
#  11  Number                1708 non-null   float64
#  12  Player Id             17172 non-null  object
#  13  Position              3096 non-null   object
# ...

# %%
# Function gives the summary statistic of a DataFrame

df.describe()
# Out:
#                 Age  Height (inches)       Number  Weight (lbs)
# count  13504.000000     17026.000000  1708.000000  17121.000000
# mean      43.839307        73.508399    51.771077    229.220665
# std       34.133513         2.577632    28.497726     42.732732
# min       19.000000        61.000000     1.000000      1.000000
# 25%       28.000000        72.000000    26.000000    195.000000
# 50%       39.000000        74.000000    52.000000    220.000000
# 75%       55.000000        75.000000    77.000000    255.000000
# max     2017.000000        82.000000    99.000000    375.000000

# %%
# Find elements in a particular index

df.loc[10]
# Out:
# Age                                    NaN
# Birth Place                   Orlando , FL
# Birthday                          3/8/1945
# College                     Tennessee Tech
# Current Status                     Retired
# Current Team                           NaN
# Experience                       3 Seasons
# Height (inches)                       76.0
# High School                            NaN
# High School Location                   NaN
# Name                          Tanner, John
# Number                                 NaN
# Player Id               johntanner/2527011
# Position                               NaN
# Weight (lbs)                         231.0
# Years Played                   1971 - 1974
# Name: 10, dtype: object

# %%
# Selecionando uma coluna especifica.
# To select a single column, use square brackets [] with the column name of the column of interest.

CurrentTeam = df["Current Team"]
CurrentTeam
# Out:
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4        Pittsburgh Steelers
#                 ...
# 17167                    NaN
# 17168                    NaN
# 17169                    NaN
# 17170                    NaN
# 17171                    NaN
# Name: Current Team, Length: 17172, dtype: object

# %%
CurrentTeam.head(50)
# Out:
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4     Pittsburgh Steelers
# 5                     NaN
# 6                     NaN
# 7           New York Jets
# 8                     NaN
# 9                     NaN
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17    Washington Redskins
# 18                    NaN
# 19                    NaN
# 20                    NaN
# 21                    NaN
# 22                    NaN
# 23                    NaN
# 24                    NaN
# 25                    NaN
# 26                    NaN
# 27                    NaN
# 28                    NaN
# 29                    NaN
# 30                    NaN
# 31                    NaN
# 32                    NaN
# 33                    NaN
# 34                    NaN
# ...

# %%
# Media de idade dos jogadores 

df_age = df["Age"].mean()
df_age
# Out:
# 43.839306872037916

# %%
# Selecionando os jogadores "ativos"

ativo = 'Active'
resultado = df[df['Current Status'] == ativo]
print(resultado)
# Out:
#         Age       Birth Place   Birthday               College Current Status
# 4      25.0      Detroit , MI  3/31/1992      Central Michigan         Active  \
# 7      22.0      Navarre , FL  1/31/1995               Clemson         Active
# 17     25.0               NaN  3/11/1992            Pittsburgh         Active
# 35     29.0       Dayton , OH   4/1/1988            Ohio State         Active
# 37     26.0        Rodeo , CA  7/28/1990               Ohio U.         Active
# ...     ...               ...        ...                   ...            ...
# 17121  21.0  Baton Rouge , LA  6/21/1995  Southern Mississippi         Active
# 17140  37.0       Wilson , NC  1/18/1980        North Carolina         Active
# 17151  27.0      Detroit , MI  2/25/1990      Western Michigan         Active
# 17155  29.0       Dayton , OH  6/24/1987            Notre Dame         Active
# 17157  28.0     Richmond , VA  1/26/1989              Maryland         Active
#
# ...

# %%
# Selecionando os jogadores do Atlanta Falcons

Atlanta_falcons = 'Atlanta Falcons'
df_atlanta_falcons = df[df['Current Team'] == Atlanta_falcons]
df_atlanta_falcons
# Out:
#         Age     Birth Place    Birthday          College       Current Status
# 215    21.0             NaN  11/22/1995          Georgia               Active  \
# 350    24.0             NaN    5/3/1993  Pittsburg State               Active
# 353    27.0    Kearney , NE   5/16/1990       Notre Dame               Active
# 597    24.0             NaN   4/10/1993       Washington               Active
# 643    34.0     Tustin , CA   1/12/1983         Oklahoma  Unsigned free agent
# ...     ...             ...         ...              ...                  ...
# 16168  26.0     Tacoma , WA   9/10/1990       Washington               Active
# 16415  22.0             NaN   3/28/1995     Oregon State               Active
# 16857  24.0   Honolulu , HI  12/13/1992       Washington               Active
# 16954  28.0  St. Louis , MO    7/6/1988             Iowa               Active
# 17048  22.0             NaN    3/4/1995          Georgia               Active
#
# ...

# %%
# Media dos jogadores do Atlanta Falcons

age_mean_atlanta_falcons = df_atlanta_falcons['Age']
age_mean_atlanta_falcons.mean()
# Out:
# 25.877551020408163
